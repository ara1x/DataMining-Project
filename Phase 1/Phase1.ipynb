# %% [markdown]
# <a href="https://colab.research.google.com/github/ara1x/DataMining-Project/blob/main/Phase%201/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Project Goal**
#
# The main objective of this project is to analyze students’ academic and demographic factors to predict and understand their levels of anxiety. Using data mining techniques, the project will:
#
#  * Classification: Categorize students into four anxiety levels (Minimal, Mild, Moderate, Severe).
#
#  * Clustering: Group students with similar anxiety patterns and academic characteristics to uncover common risk factors.
#
# Beyond analysis, this project aims to shed light on the psychological challenges students face, helping to create a more supportive educational environment that reduces anxiety and promotes student well being.
#
# ## **Dataset Source**
#
# This project utilizes anxiety data from university students, which were part of a broader study examining anxiety, stress, and depression. In this project, the focus is specifically on anxiety.
#
# URL: https://figshare.com/articles/dataset/MHP_Anxiety_Stress_Depression_Dataset_of_University_Students/25771164?file=46172340

# %% [markdown]
# ## **Dataset Description**

# %%
import pandas as pd

data = pd.read_excel("Anxiety..xlsx")

# %% [markdown]
# ## **Number of Objects**

# %%
print("Shape of dataset (rows, columns):", data.shape)
# Out:
# Shape of dataset (rows, columns): (2028, 16)

# %% [markdown]
# ## **Class Attribute and Counts**

# %%
print(data['Anxiety Label'].value_counts())
# Out:
# Anxiety Label
# Severe Anxiety      744
# Moderate Anxiety    620
# Mild Anxiety        505
# Minimal Anxiety     159
# Name: count, dtype: int64

# %% [markdown]
# ## **Number and Data Types of Attributes**

# %%
data.dtypes
# Out:
# 1. Age                         object
# 2. Gender                      object
# 3. University                  object
# 4. Department                  object
# 5. Academic Year               object
# 6. Current CGPA                object
# 7. Scholarship                 object
# Academic_Anxiety_Level          int64
# Academic_Worry_Level            int64
# Relaxation_Difficulty_Level     int64
# Academic_Irritation_Level       int64
# Excessive_Worry_Level           int64
# Academic_Restlessness_Level     int64
# Fear_Level                      int64
# Anxiety Value                   int64
# Anxiety Label                  object
# dtype: object

# %% [markdown]
# ## **The possible values for each attribute**

# %%
attributes_info=[]
for col in data.columns:
 if data[col].dtype=='object':
  possible_values=list(data[col].unique())
  value_range=",".join(map(str,possible_values[:10]))
  attributes_info.append({
    'Attribute': col,
    'Type': 'Categorical',
    'Possible Values': value_range
})
else:
 min_val = data[col].min()
 max_val = data[col].max()
 attributes_info.append({
   'Attribute': col ,
   'type': 'Numerical',
   'possible Values':f"From {min_val} To {max_val}"
})
result=pd.DataFrame(attributes_info)
display(result)
# Out:
#           Attribute         Type  \
# 0            1. Age  Categorical
# 1         2. Gender  Categorical
# 2     3. University  Categorical
# 3     4. Department  Categorical
# 4  5. Academic Year  Categorical
# 5   6. Current CGPA  Categorical
# 6    7. Scholarship  Categorical
# 7     Anxiety Label  Categorical
# 8     Anxiety Label          NaN
#
#                                      Possible Values       type  \
# 0                18-22,23-26,27-30,Above 30,Below 18        NaN
# 1                      Female,Male,Prefer not to say        NaN
# 2  Independent University, Bangladesh (IUB),Ameri...        NaN
# 3  Engineering - CS / CSE / CSC / Similar to CS,E...        NaN
# 4  Second Year or Equivalent,Third Year or Equiva...        NaN
# 5  2.50 - 2.99,3.00 - 3.39,3.40 - 3.79,3.80 - 4.0...        NaN
# 6                                             No,Yes        NaN
# 7  Severe Anxiety,Moderate Anxiety,Minimal Anxiet...        NaN
# 8                                                NaN  Numerical
#
#                        possible Values
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8  From Mild Anxiety To Severe Anxiety

# %% [markdown]
# ## **Sample of the Raw Dataset**

# %%
data.head()
# Out:
#   1. Age 2. Gender                                      3. University  \
# 0  18-22    Female           Independent University, Bangladesh (IUB)
# 1  18-22      Male           Independent University, Bangladesh (IUB)
# 2  18-22      Male  American International University Bangladesh (...
# 3  18-22      Male  American International University Bangladesh (...
# 4  18-22      Male                       North South University (NSU)
#
#                                   4. Department           5. Academic Year  \
# 0  Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
# 1  Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 2  Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 3  Engineering - CS / CSE / CSC / Similar to CS   Third Year or Equivalent
# 4  Engineering - CS / CSE / CSC / Similar to CS  Second Year or Equivalent
#
#   6. Current CGPA 7. Scholarship  Academic_Anxiety_Level   \
# 0     2.50 - 2.99             No                        2
# 1     3.00 - 3.39             No                        1
# 2     3.00 - 3.39             No                        0
# 3     3.00 - 3.39             No                        2
# 4     2.50 - 2.99             No                        3
#
#    Academic_Worry_Level  Relaxation_Difficulty_Level  \
# 0                     2                            3
# 1                     2                            2
# 2                     0                            0
# 3                     1                            1
# 4                     0                            3
#
#    Academic_Irritation_Level  Excessive_Worry_Level  \
# 0                          2                      2
# 1                          1                      1
# 2                          0                      0
# 3                          1                      2
# 4                          3                      1
#
#    Academic_Restlessness_Level  Fear_Level  Anxiety Value     Anxiety Label
# 0                            2           2             15    Severe Anxiety
# 1                            3           2             12  Moderate Anxiety
# 2                            0           0              0   Minimal Anxiety
# 3                            1           2             10  Moderate Anxiety
# 4                            1           3             14  Moderate Anxiety
