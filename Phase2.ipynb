# %% [markdown]
# <a href="https://colab.research.google.com/github/ara1x/DataMining-Project/blob/main/Phase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel('Anxiety..xlsx')
df1=pd.DataFrame(df)

# %%
print(df1.describe())
print(df1.describe(include=['object']))
# Out:
#        Academic_Anxiety_Level   Academic_Worry_Level  \
# count              2028.000000           2028.000000
# mean                  1.778107              1.634122
# std                   0.952277              1.027620
# min                   0.000000              0.000000
# 25%                   1.000000              1.000000
# 50%                   2.000000              2.000000
# 75%                   3.000000              3.000000
# max                   3.000000              3.000000
#
#        Relaxation_Difficulty_Level  Academic_Irritation_Level  \
# count                  2028.000000                2028.000000
# mean                      1.754438                   1.782544
# std                       0.996221                   0.965386
# min                       0.000000                   0.000000
# 25%                       1.000000                   1.000000
# 50%                       2.000000                   2.000000
# 75%                       3.000000                   3.000000
# max                       3.000000                   3.000000
#
#        Excessive_Worry_Level  Academic_Restlessness_Level   Fear_Level  \
# count            2028.000000                  2028.000000  2028.000000
# mean                1.865878                     1.797337     1.732742
# std                 0.982209                     0.992748     1.057113
# min                 0.000000                     0.000000     0.000000
# 25%                 1.000000                     1.000000     1.000000
# 50%                 2.000000                     2.000000     2.000000
# 75%                 3.000000                     3.000000     3.000000
# max                 3.000000                     3.000000     3.000000
#
#        Anxiety Value
# count    2028.000000
# mean       12.345168
# std         5.493521
# min         0.000000
# 25%         8.000000
# 50%        13.000000
# 75%        17.000000
# max        21.000000
#        1. Age 2. Gender                             3. University  \
# count    2028      2028                                      2028
# unique      5         3                                        15
# top     18-22      Male  Independent University, Bangladesh (IUB)
# freq     1304      1405                                       532
#
#                                        4. Department  \
# count                                           2028
# unique                                            12
# top     Engineering - CS / CSE / CSC / Similar to CS
# freq                                            1409
#
#                 5. Academic Year 6. Current CGPA 7. Scholarship  \
# count                       2028            2028           2028
# unique                         5               6              2
# top     First Year or Equivalent     3.00 - 3.39             No
# freq                         601             583           1602
#
#          Anxiety Label
# count             2028
# unique               4
# top     Severe Anxiety
# freq               744

# %%
missing=df.isna().sum()
print("The Missing Values in each column:")
print(missing)
print("\n Total Number Of Missing Values In The Dataset:",null_values.sum())
# Out:
# The Missing Values in each column:
# 1. Age                         0
# 2. Gender                      0
# 3. University                  0
# 4. Department                  0
# 5. Academic Year               0
# 6. Current CGPA                0
# 7. Scholarship                 0
# Academic_Anxiety_Level         0
# Academic_Worry_Level           0
# Relaxation_Difficulty_Level    0
# Academic_Irritation_Level      0
# Excessive_Worry_Level          0
# Academic_Restlessness_Level    0
# Fear_Level                     0
# Anxiety Value                  0
# Anxiety Label                  0
# dtype: int64
#
#  Total Number Of Missing Values In The Dataset: 0

# %%
plt.figure(figsize=(16,6))
missing.plot(kind='bar')
plt.title("The Missing Values Per Column")
plt.ylabel("Count Of Missing Values")
plt.xticks(rotation=90,ha='right')
plt.show()

# %% [markdown]
# The bar char show that **no** **missing** **values**. This indicates that the data is complete, and there is no need to apply any methods for handling missing values.

# %%
print(df['Anxiety Label'].value_counts())
sns.countplot(data=df, x='Anxiety Label')
plt.title("Anxiety Levels")
plt.show()
# Out:
# Anxiety Label
# Severe Anxiety      744
# Moderate Anxiety    620
# Mild Anxiety        505
# Minimal Anxiety     159
# Name: count, dtype: int64

# %% [markdown]
# The bar chart shows that (Severe Anxiety) is the most common category in the sample, followed by (Moderate) and (Mild) with (Minimal Anxiety) being the least. This indicates that higher anxiety levels dominate the dataset, which is important for understanding the problem and guiding the choice of analysis methods.

# %% [markdown]
# # **Five number summary**

# %% [markdown]
# ## **Outliers**

# %% [markdown]
# ## **Boxplot**

# %% [markdown]
# ## **Bar chart**

# %% [markdown]
# ## **Scatter plot**

# %% [markdown]
# ## **Histogram**
