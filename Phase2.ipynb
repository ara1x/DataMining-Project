# %% [markdown]
# <a href="https://colab.research.google.com/github/ara1x/DataMining-Project/blob/main/Phase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('Anxiety.csv')

# %%
print(df.describe())
print(df.describe(include=['object']))
# Out:
#        1. In a semester, how often you felt nervous, anxious or on edge due to academic pressure?   \
# count                                        2028.000000
# mean                                            1.778107
# std                                             0.952277
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        2. In a semester, how often have you been unable to stop worrying about your academic affairs?   \
# count                                        2028.000000
# mean                                            1.634122
# std                                             1.027620
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        3. In a semester, how often have you had trouble relaxing due to academic pressure?   \
# count                                        2028.000000
# mean                                            1.754438
# std                                             0.996221
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        4. In a semester, how often have you been easily annoyed or irritated because of academic pressure?  \
# count                                        2028.000000
# mean                                            1.782544
# std                                             0.965386
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        5. In a semester, how often have you worried too much about academic affairs?   \
# count                                        2028.000000
# mean                                            1.865878
# std                                             0.982209
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        6. In a semester, how often have you been so restless due to academic pressure that it is hard to sit still?  \
# count                                        2028.000000
# mean                                            1.797337
# std                                             0.992748
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        7. In a semester, how often have you felt afraid, as if something awful might happen?  \
# count                                        2028.000000
# mean                                            1.732742
# std                                             1.057113
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        Anxiety Value
# count    2028.000000
# mean       12.345168
# std         5.493521
# min         0.000000
# 25%         8.000000
# 50%        13.000000
# 75%        17.000000
# max        21.000000
#        1. Age 2. Gender                             3. University  \
# count    2028      2028                                      2028
# unique      5         3                                        15
# top     18-22      Male  Independent University, Bangladesh (IUB)
# freq     1304      1405                                       532
#
#                                        4. Department  \
# count                                           2028
# unique                                            12
# top     Engineering - CS / CSE / CSC / Similar to CS
# freq                                            1409
#
#                 5. Academic Year 6. Current CGPA  \
# count                       2028            2028
# unique                         5               6
# top     First Year or Equivalent     3.00 - 3.39
# freq                         601             583
#
#        7. Did you receive a waiver or scholarship at your university?  \
# count                                                2028
# unique                                                  2
# top                                                    No
# freq                                                 1602
#
#          Anxiety Label
# count             2028
# unique               4
# top     Severe Anxiety
# freq               744

# %%
print(df.isnull().sum())
print((df.isnull().mean())*100)
# Out:
# 1. Age                                                                                                          0
# 2. Gender                                                                                                       0
# 3. University                                                                                                   0
# 4. Department                                                                                                   0
# 5. Academic Year                                                                                                0
# 6. Current CGPA                                                                                                 0
# 7. Did you receive a waiver or scholarship at your university?                                                  0
# 1. In a semester, how often you felt nervous, anxious or on edge due to academic pressure?                      0
# 2. In a semester, how often have you been unable to stop worrying about your academic affairs?                  0
# 3. In a semester, how often have you had trouble relaxing due to academic pressure?                             0
# 4. In a semester, how often have you been easily annoyed or irritated because of academic pressure?             0
# 5. In a semester, how often have you worried too much about academic affairs?                                   0
# 6. In a semester, how often have you been so restless due to academic pressure that it is hard to sit still?    0
# 7. In a semester, how often have you felt afraid, as if something awful might happen?                           0
# Anxiety Value                                                                                                   0
# Anxiety Label                                                                                                   0
# dtype: int64
# 1. Age                                                                                                          0.0
# 2. Gender                                                                                                       0.0
# 3. University                                                                                                   0.0
# 4. Department                                                                                                   0.0
# 5. Academic Year                                                                                                0.0
# 6. Current CGPA                                                                                                 0.0
# 7. Did you receive a waiver or scholarship at your university?                                                  0.0
# 1. In a semester, how often you felt nervous, anxious or on edge due to academic pressure?                      0.0
# 2. In a semester, how often have you been unable to stop worrying about your academic affairs?                  0.0
# 3. In a semester, how often have you had trouble relaxing due to academic pressure?                             0.0
# 4. In a semester, how often have you been easily annoyed or irritated because of academic pressure?             0.0
# 5. In a semester, how often have you worried too much about academic affairs?                                   0.0
# 6. In a semester, how often have you been so restless due to academic pressure that it is hard to sit still?    0.0
# 7. In a semester, how often have you felt afraid, as if something awful might happen?                           0.0
# Anxiety Value                                                                                                   0.0
# Anxiety Label                                                                                                   0.0
# dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False,cmap="viridis")
plt.title("Heatmap Of The Missing Values")
plt.show()

# %%
print(df['Anxiety Label'].value_counts())
sns.countplot(data=df, x='Anxiety Label')
plt.title("Anxiety Levels")
plt.show()
# Out:
# Anxiety Label
# Severe Anxiety      744
# Moderate Anxiety    620
# Mild Anxiety        505
# Minimal Anxiety     159
# Name: count, dtype: int64
